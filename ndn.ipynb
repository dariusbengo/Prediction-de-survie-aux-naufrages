# %% [markdown]
# ### Ajout de données externes
#
# ##### Conditions météorologiques
#
# Lors du naufrage du Titanic, d'après les rapports historiques, cela s'est déroulé la nuit, la mer était très calme, il y avait une bonne visibilité, peu de vent et une présence massive d’icebergs.

# %%
titanic_clean["meteo_jour"]="Jour"
titanic_clean["meteo_mer"]="Calme"
titanic_clean["meteo_vent"]="Faible"
titanic_clean["meteo_visibilite"]="Bonne"

# %% [markdown]
# D'après les rapports historiques, c'est une attaque qui a provoqué le naufrage du RMS Lusitania. Cela s'était déroulé la nuit, la mer était très calme, il y avait une bonne visibilité, peu de vent et une présence massive d’icebergs.

# %% [markdown]
# On va regrouper les 3 tables nettoyées ensemble

# %%
naufrages = pd.concat([titanic_clean, lusitania_clean, estonia_clean], ignore_index=True)
naufrages

# %%
naufrages.to_csv("data/processed/naufrages.csv", index=False)
